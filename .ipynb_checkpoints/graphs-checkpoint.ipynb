# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
def float_to_int(x):
    split_string = x.split(".", 1)
    substring = split_string[0]
    if len(substring) > 0: 
        return int(substring) 
    else: 
        return ''

all_cities_full = pd.read_csv('jaimie.csv', converters={'calendar_year': float_to_int})
all_cities_full
# Out:
#      calendar_year     city state closed_date  amount_awarded  \
# 0             2019  Chicago    IL  2019-01-29        160000.0
# 1             2018  Chicago    IL  2018-10-02        100000.0
# 2             2019  Chicago    IL  2019-05-30         70000.0
# 3             2010  Chicago    IL  2010-09-24         60000.0
# 4             2010  Chicago    IL  2010-03-18         99000.0
# ...            ...      ...   ...         ...             ...
# 2838          2020  Orlando    FL  2020-06-25         95000.0
# 2839          2016  Orlando    FL  2016-10-20          5000.0
# 2840          2020  Orlando    FL  2020-06-10         50000.0
# 2841          2019  Orlando    FL  2019-01-07         15000.0
# 2842          2019  Orlando    FL  2019-08-23         25000.0
#
#      incident_date_full incident_date
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# ...                 ...           ...
# 2838                NaN    2015-06-04
# 2839                NaN    2014-07-05
# 2840                NaN    2016-01-06
# 2841                NaN    2017-03-04
# 2842                NaN    2018-01-04
#
# [2843 rows x 7 columns]

# %%
boston_filter = all_cities_full[all_cities_full.city == "Boston"]

# %%
boston_filter
# Out:
#      calendar_year    city state closed_date  amount_awarded  \
# 2599          2010  Boston    MA  2010-01-14         2000.00
# 2600          2010  Boston    MA         NaN        85000.00
# 2601          2010  Boston    MA  2010-05-05         6000.00
# 2602          2010  Boston    MA  2010-05-27        12000.00
# 2603          2010  Boston    MA  2010-08-14        25000.00
# 2604          2010  Boston    MA  2010-10-10        15000.00
# 2605          2010  Boston    MA  2010-12-28        16950.00
# 2606          2011  Boston    MA  2011-03-01        11000.00
# 2607          2011  Boston    MA  2011-10-28        34500.00
# 2608          2012  Boston    MA  2012-02-16      1400000.00
# 2609          2012  Boston    MA  2012-03-05       170000.00
# 2610          2012  Boston    MA  2012-04-18        60000.00
# 2611          2012  Boston    MA         NaN        33000.00
# 2612          2012  Boston    MA  2012-07-11         6000.00
# 2613          2012  Boston    MA  2012-07-19       150000.00
# 2614          2012  Boston    MA  2012-09-12        30000.00
# 2615          2012  Boston    MA  2012-10-09        25000.00
# 2616          2012  Boston    MA  2012-10-12       115000.00
# 2617          2013  Boston    MA  2013-01-25        20000.00
# 2618          2013  Boston    MA  2013-05-03        50000.00
# 2619          2013  Boston    MA  2013-05-03       239139.50
# 2620          2013  Boston    MA  2013-06-26        85000.00
# 2621          2013  Boston    MA         NaN        10000.00
# 2622          2013  Boston    MA  2013-09-20      3000000.00
# 2623          2013  Boston    MA  2013-10-22        75000.00
# 2624          2013  Boston    MA  2013-10-25        12000.00
# 2625          2014  Boston    MA  2014-03-14      5000000.00
# 2626          2014  Boston    MA  2014-05-15        50000.00
# 2627          2014  Boston    MA  2014-06-02       100000.00
# 2628          2014  Boston    MA  2014-12-12        25000.00
# 2629          2015  Boston    MA         NaN        75000.00
# 2630          2015  Boston    MA         NaN        18500.00
# 2631          2015  Boston    MA  2015-06-09        29000.00
# 2632          2015  Boston    MA  2015-06-10        52500.00
# 2633          2015  Boston    MA  2015-10-15         5000.00
# 2634          2015  Boston    MA  2015-11-18       179892.36
# 2635          2016  Boston    MA  2016-11-07        45000.00
# 2636          2016  Boston    MA  2016-03-16        18000.00
# 2637          2016  Boston    MA  2016-06-06       120000.00
# 2638          2016  Boston    MA  2016-07-15        12500.00
# 2639          2016  Boston    MA  2016-09-12        12500.00
# 2640          2017  Boston    MA  2017-05-05         5000.00
# 2641          2017  Boston    MA  2017-07-05         5000.00
# 2642          2017  Boston    MA  2017-07-06        60000.00
# 2643          2018  Boston    MA  2018-02-16        15000.00
# 2644          2018  Boston    MA  2018-08-14         5000.00
# 2645          2018  Boston    MA  2018-09-25        10000.00
# 2646          2018  Boston    MA  2018-10-30       250000.00
# 2647          2018  Boston    MA  2018-12-20        10000.00
# 2648          2019  Boston    MA  2019-01-30       100000.00
# 2649          2019  Boston    MA  2019-05-19        15000.00
#
#      incident_date_full incident_date
# 2599                NaN           NaN
# 2600                NaN           NaN
# 2601                NaN           NaN
# 2602                NaN           NaN
# 2603                NaN           NaN
# 2604                NaN           NaN
# 2605                NaN           NaN
# 2606                NaN           NaN
# 2607                NaN           NaN
# 2608                NaN           NaN
# 2609                NaN           NaN
# 2610                NaN           NaN
# 2611                NaN           NaN
# 2612                NaN           NaN
# 2613                NaN           NaN
# 2614                NaN           NaN
# 2615                NaN           NaN
# 2616                NaN           NaN
# 2617                NaN           NaN
# 2618                NaN           NaN
# 2619                NaN           NaN
# 2620                NaN           NaN
# 2621                NaN           NaN
# 2622                NaN           NaN
# 2623                NaN           NaN
# 2624                NaN           NaN
# 2625                NaN           NaN
# 2626                NaN           NaN
# 2627                NaN           NaN
# 2628                NaN           NaN
# 2629                NaN           NaN
# 2630                NaN           NaN
# 2631                NaN           NaN
# 2632                NaN           NaN
# 2633                NaN           NaN
# 2634                NaN           NaN
# 2635                NaN           NaN
# 2636                NaN           NaN
# 2637                NaN           NaN
# 2638                NaN           NaN
# 2639                NaN           NaN
# 2640                NaN           NaN
# 2641                NaN           NaN
# 2642                NaN           NaN
# 2643                NaN           NaN
# 2644                NaN           NaN
# 2645                NaN           NaN
# 2646                NaN           NaN
# 2647                NaN           NaN
# 2648                NaN           NaN
# 2649                NaN           NaN

# %%
boston_columns = boston_filter.loc[:, ['city', 'calendar_year', 'amount_awarded']]

# %%
boston_columns
# Out:
#         city calendar_year  amount_awarded
# 2599  Boston          2010         2000.00
# 2600  Boston          2010        85000.00
# 2601  Boston          2010         6000.00
# 2602  Boston          2010        12000.00
# 2603  Boston          2010        25000.00
# 2604  Boston          2010        15000.00
# 2605  Boston          2010        16950.00
# 2606  Boston          2011        11000.00
# 2607  Boston          2011        34500.00
# 2608  Boston          2012      1400000.00
# 2609  Boston          2012       170000.00
# 2610  Boston          2012        60000.00
# 2611  Boston          2012        33000.00
# 2612  Boston          2012         6000.00
# 2613  Boston          2012       150000.00
# 2614  Boston          2012        30000.00
# 2615  Boston          2012        25000.00
# 2616  Boston          2012       115000.00
# 2617  Boston          2013        20000.00
# 2618  Boston          2013        50000.00
# 2619  Boston          2013       239139.50
# 2620  Boston          2013        85000.00
# 2621  Boston          2013        10000.00
# 2622  Boston          2013      3000000.00
# 2623  Boston          2013        75000.00
# 2624  Boston          2013        12000.00
# 2625  Boston          2014      5000000.00
# 2626  Boston          2014        50000.00
# 2627  Boston          2014       100000.00
# 2628  Boston          2014        25000.00
# 2629  Boston          2015        75000.00
# 2630  Boston          2015        18500.00
# 2631  Boston          2015        29000.00
# 2632  Boston          2015        52500.00
# 2633  Boston          2015         5000.00
# 2634  Boston          2015       179892.36
# 2635  Boston          2016        45000.00
# 2636  Boston          2016        18000.00
# 2637  Boston          2016       120000.00
# 2638  Boston          2016        12500.00
# 2639  Boston          2016        12500.00
# 2640  Boston          2017         5000.00
# 2641  Boston          2017         5000.00
# 2642  Boston          2017        60000.00
# 2643  Boston          2018        15000.00
# 2644  Boston          2018         5000.00
# 2645  Boston          2018        10000.00
# 2646  Boston          2018       250000.00
# 2647  Boston          2018        10000.00
# 2648  Boston          2019       100000.00
# 2649  Boston          2019        15000.00

# %%
boston_graph_mean = boston_filter.groupby(['calendar_year'])[['amount_awarded']].mean()

# %%
boston_graph_mean.round()
# Out:
#                amount_awarded
# calendar_year
# 2010                  23136.0
# 2011                  22750.0
# 2012                 221000.0
# 2013                 436392.0
# 2014                1293750.0
# 2015                  59982.0
# 2016                  41600.0
# 2017                  23333.0
# 2018                  58000.0
# 2019                  57500.0

# %%
boston_graph_sum = boston_filter.groupby(['calendar_year'])[['amount_awarded']].sum()

# %%
boston_graph_sum
# Out:
#                amount_awarded
# calendar_year
# 2010                161950.00
# 2011                 45500.00
# 2012               1989000.00
# 2013               3491139.50
# 2014               5175000.00
# 2015                359892.36
# 2016                208000.00
# 2017                 70000.00
# 2018                290000.00
# 2019                115000.00

# %%
plot = boston_graph_mean.plot.bar()
plot.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plot.set_title('Boston City Average Payout For Police Misconduct By Year')
plot.set_xlabel('Year')
plot.set_ylabel('Amount Awarded')
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
boston_graph = boston_graph_mean.plot()
boston_graph.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
boston_graph.set_title('Boston City Average Payout For Police Misconduct By Year')
boston_graph.set_xlabel('Year')
boston_graph.set_ylabel('Amount Awarded')
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
plot = boston_graph_mean.plot.barh()
plt.gcf().axes[0].xaxis.get_major_formatter().set_scientific(False)
plot.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plot.set_title('Boston City Average Payout For Police Misconduct By Year')
plot.set_xlabel('Amount Awarded')
plot.set_ylabel('Year')
# Out:
# Text(0, 0.5, 'Year')
