# %%
import pandas as pd
pd.set_option('display.max_rows', None)
df = pd.read_csv('final2.csv')
df
# Out:
#     Unnamed: 0  calendar_year  amount_awarded           city
# 0            0           2010        161950.0         Boston
# 1            1           2011         45500.0         Boston
# 2            2           2012       1989000.0         Boston
# 3            3           2013       3491140.0         Boston
# 4            4           2014       5175000.0         Boston
# 5            5           2015        359892.0         Boston
# 6            6           2016        208000.0         Boston
# 7            7           2017         70000.0         Boston
# 8            8           2018        290000.0         Boston
# 9            9           2019        115000.0         Boston
# 10          10           2010          5500.0     Charleston
# 11          11           2011          4000.0     Charleston
# 12          12           2012         35500.0     Charleston
# 13          13           2013         84000.0     Charleston
# ...

# %%
df2 = df.pop['column' = Unnamed: 0], inplace=True
