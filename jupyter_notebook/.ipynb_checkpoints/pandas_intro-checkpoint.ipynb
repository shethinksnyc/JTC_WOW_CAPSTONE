# %%
import pandas as pd

# %%
df = pd.read_csv('censusPovertyData.csv')

# %%
df
# Out:
#                       Table with column headers in row 3       Unnamed: 1  \
# 0      2018 Poverty Estimates for School districts   ...              NaN
# 1                                      State Postal Code  State FIPS Code
# 2                                                     AL               01
# 3                                                     AL               01
# 4                                                     AL               01
# ...                                                  ...              ...
# 13205                                                 WY               56
# 13206                                                 WY               56
# 13207                                                 WY               56
# 13208                                                 PR               72
# 13209                                                NaN              NaN
#
#         Unnamed: 2                           Unnamed: 3  \
# ...

# %%
df.head(10)
# Out:
#                   Table with column headers in row 3       Unnamed: 1  \
# 0  2018 Poverty Estimates for School districts   ...              NaN
# 1                                  State Postal Code  State FIPS Code
# 2                                                 AL               01
# 3                                                 AL               01
# 4                                                 AL               01
# 5                                                 AL               01
# 6                                                 AL               01
# 7                                                 AL               01
# 8                                                 AL               01
# 9                                                 AL               01
#
#     Unnamed: 2                           Unnamed: 3  \
# 0          NaN                                  NaN
# 1  District ID                                 Name
# ...

# %%
df.tail(10)
# Out:
#       Table with column headers in row 3 Unnamed: 1 Unnamed: 2  \
# 13200                                 WY         56      05830
# 13201                                 WY         56      02760
# 13202                                 WY         56      04500
# 13203                                 WY         56      04260
# 13204                                 WY         56      06240
# 13205                                 WY         56      05820
# 13206                                 WY         56      04830
# 13207                                 WY         56      06090
# 13208                                 PR         72      00030
# 13209                                NaN        NaN        NaN
#
#                               Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 13200     Teton County School District 1     23,081      3,107        180
# 13201     Uinta County School District 1     14,061      2,927        367
# ...

# %%
df.shape
# Out:
# (13210, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13210 entries, 0 to 13209
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Table with column headers in row 3  13209 non-null  object
#  1   Unnamed: 1                          13208 non-null  object
#  2   Unnamed: 2                          13208 non-null  object
#  3   Unnamed: 3                          13208 non-null  object
#  4   Unnamed: 4                          13208 non-null  object
#  5   Unnamed: 5                          13208 non-null  object
#  6   Unnamed: 6                          13208 non-null  object
# dtypes: object(7)
# memory usage: 722.5+ KB

# %%
df.columns[3]
# Out:
# 'Unnamed: 3'

# %%
df.rename(columns = {'Unnamed: 1': 'Col_1'}, inplace = True)

# %%
df
# Out:
#                       Table with column headers in row 3            Col_1  \
# 0      2018 Poverty Estimates for School districts   ...              NaN
# 1                                      State Postal Code  State FIPS Code
# 2                                                     AL               01
# 3                                                     AL               01
# 4                                                     AL               01
# ...                                                  ...              ...
# 13205                                                 WY               56
# 13206                                                 WY               56
# 13207                                                 WY               56
# 13208                                                 PR               72
# 13209                                                NaN              NaN
#
#         Unnamed: 2                           Unnamed: 3  \
# ...

# %%
df.drop([0], inplace = True)

# %%
df
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 1                      State Postal Code  State FIPS Code  District ID
# 2                                     AL               01        00190
# 3                                     AL               01        00005
# 4                                     AL               01        00030
# 5                                     AL               01        00060
# ...                                  ...              ...          ...
# 13205                                 WY               56        05820
# 13206                                 WY               56        04830
# 13207                                 WY               56        06090
# 13208                                 PR               72        00030
# 13209                                NaN              NaN          NaN
#
#                                 Unnamed: 3                  Unnamed: 4  \
# ...

# %%
df.sort_values('Unnamed: 4')
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 4419                                  ME               23        82013
# 4486                                  ME               23        82004
# 9286                                  OH               39        04896
# 4409                                  ME               23        82007
# 4415                                  ME               23        82006
# ...                                  ...              ...          ...
# 2480                                  IL               17        10860
# 8810                                  ND               38        00057
# 1553                                  CA               06        42270
# 1                      State Postal Code  State FIPS Code  District ID
# 13209                                NaN              NaN          NaN
#
#                                               Unnamed: 3  \
# ...

# %%
df.sort_values(['Unnamed: 3'], ascending = True)
# Out:
#       Table with column headers in row 3 Col_1 Unnamed: 2  \
# 2315                                  IL    17      00105
# 5445                                  MN    27      00106
# 645                                   CA    06      01620
# 3455                                  IA    19      03060
# 3456                                  IA    19      04080
# ...                                  ...   ...        ...
# 3454                                  IN    18      02830
# 5782                                  MN    27      45735
# 7926                                  NM    35      02800
# 6839                                  MT    30      28910
# 13209                                NaN   NaN        NaN
#
#                                            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2315   A-C Central Community Unit School District 262      2,360        380
# 5445                  A.C.G.C. Public School District      5,906        996
# ...

# %%
df.dropna()
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 1                      State Postal Code  State FIPS Code  District ID
# 2                                     AL               01        00190
# 3                                     AL               01        00005
# 4                                     AL               01        00030
# 5                                     AL               01        00060
# ...                                  ...              ...          ...
# 13204                                 WY               56        06240
# 13205                                 WY               56        05820
# 13206                                 WY               56        04830
# 13207                                 WY               56        06090
# 13208                                 PR               72        00030
#
#                                 Unnamed: 3                  Unnamed: 4  \
# ...

# %%
df.sort_values(['Unnamed: 3'], ascending = True)
# Out:
#       Table with column headers in row 3 Col_1 Unnamed: 2  \
# 2315                                  IL    17      00105
# 5445                                  MN    27      00106
# 645                                   CA    06      01620
# 3455                                  IA    19      03060
# 3456                                  IA    19      04080
# ...                                  ...   ...        ...
# 3454                                  IN    18      02830
# 5782                                  MN    27      45735
# 7926                                  NM    35      02800
# 6839                                  MT    30      28910
# 13209                                NaN   NaN        NaN
#
#                                            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2315   A-C Central Community Unit School District 262      2,360        380
# 5445                  A.C.G.C. Public School District      5,906        996
# ...

# %%
df.dropna()
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 1                      State Postal Code  State FIPS Code  District ID
# 2                                     AL               01        00190
# 3                                     AL               01        00005
# 4                                     AL               01        00030
# 5                                     AL               01        00060
# ...                                  ...              ...          ...
# 13204                                 WY               56        06240
# 13205                                 WY               56        05820
# 13206                                 WY               56        04830
# 13207                                 WY               56        06090
# 13208                                 PR               72        00030
#
#                                 Unnamed: 3                  Unnamed: 4  \
# ...

# %%
df
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 1                      State Postal Code  State FIPS Code  District ID
# 2                                     AL               01        00190
# 3                                     AL               01        00005
# 4                                     AL               01        00030
# 5                                     AL               01        00060
# ...                                  ...              ...          ...
# 13205                                 WY               56        05820
# 13206                                 WY               56        04830
# 13207                                 WY               56        06090
# 13208                                 PR               72        00030
# 13209                                NaN              NaN          NaN
#
#                                 Unnamed: 3                  Unnamed: 4  \
# ...

# %%
df
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 1                      State Postal Code  State FIPS Code  District ID
# 2                                     AL               01        00190
# 3                                     AL               01        00005
# 4                                     AL               01        00030
# 5                                     AL               01        00060
# ...                                  ...              ...          ...
# 13205                                 WY               56        05820
# 13206                                 WY               56        04830
# 13207                                 WY               56        06090
# 13208                                 PR               72        00030
# 13209                                NaN              NaN          NaN
#
#                                 Unnamed: 3                  Unnamed: 4  \
# ...

# %%
df.sort_values(['Unnamed: 3'], ascending = True)
# Out:
#       Table with column headers in row 3 Col_1 Unnamed: 2  \
# 2315                                  IL    17      00105
# 5445                                  MN    27      00106
# 645                                   CA    06      01620
# 3455                                  IA    19      03060
# 3456                                  IA    19      04080
# ...                                  ...   ...        ...
# 3454                                  IN    18      02830
# 5782                                  MN    27      45735
# 7926                                  NM    35      02800
# 6839                                  MT    30      28910
# 13209                                NaN   NaN        NaN
#
#                                            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2315   A-C Central Community Unit School District 262      2,360        380
# 5445                  A.C.G.C. Public School District      5,906        996
# ...

# %%
df.dropna()
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 1                      State Postal Code  State FIPS Code  District ID
# 2                                     AL               01        00190
# 3                                     AL               01        00005
# 4                                     AL               01        00030
# 5                                     AL               01        00060
# ...                                  ...              ...          ...
# 13204                                 WY               56        06240
# 13205                                 WY               56        05820
# 13206                                 WY               56        04830
# 13207                                 WY               56        06090
# 13208                                 PR               72        00030
#
#                                 Unnamed: 3                  Unnamed: 4  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       Table with column headers in row 3            Col_1   Unnamed: 2  \
# 1                      State Postal Code  State FIPS Code  District ID
# 2                                     AL               01        00190
# 3                                     AL               01        00005
# 4                                     AL               01        00030
# 5                                     AL               01        00060
# ...                                  ...              ...          ...
# 13204                                 WY               56        06240
# 13205                                 WY               56        05820
# 13206                                 WY               56        04830
# 13207                                 WY               56        06090
# 13208                                 PR               72        00030
#
#                                 Unnamed: 3                  Unnamed: 4  \
# ...
