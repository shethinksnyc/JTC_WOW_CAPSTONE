# %%
import pandas as pd

# %%
miami_full = pd.read_csv('miami_edited.csv')

# %%
miami_full
# Out:
#     calendar_year   city state  incident_date  incident_year  filed_date  \
# 0            2010  Miami    FL            NaN            NaN  2005-10-04
# 1            2010  Miami    FL            NaN            NaN  2006-05-08
# 2            2011  Miami    FL            NaN            NaN  2007-08-01
# 3            2011  Miami    FL            NaN            NaN  2007-08-10
# 4            2010  Miami    FL            NaN            NaN  2007-10-11
# ..            ...    ...   ...            ...            ...         ...
# 82           2015  Miami    FL            NaN            NaN  2014-05-15
# 83           2017  Miami    FL            NaN            NaN  2014-06-05
# 84           2020  Miami    FL            NaN            NaN         NaN
# 85           2018  Miami    FL            NaN            NaN  2017-06-14
# 86           2018  Miami    FL            NaN            NaN         NaN
#
#     filed_year closed_date  amount_awarded  other_expenses  ...  \
# ...

# %%
miami_yearly = miami_full.groupby('calendar_year')[['amount_awarded']].sum()

# %%
miami_yearly
# Out:
#                amount_awarded
# calendar_year
# 2010                124500.00
# 2011                632431.00
# 2012                466750.00
# 2013                285768.00
# 2014                113385.00
# 2015                577550.00
# 2016               1970512.10
# 2017                381048.00
# 2018               1892198.00
# 2019                175641.76
# 2020                664900.00

# %%
los_angeles_full = pd.read_csv('los_angeles_edited.csv')

# %%
los_angeles_yearly = los_angeles_full.groupby('calendar_year')[['amount_awarded']].sum()

# %%
los_angeles_yearly_round = los_angeles_yearly.round()
