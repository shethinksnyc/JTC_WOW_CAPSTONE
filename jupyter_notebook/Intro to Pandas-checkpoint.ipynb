# %% [markdown]
# # Intro to Pandas

# %%
import pandas as pd

# %% [markdown]
# This is how you import data into Python using Pandas:

# %%
df = pd.read_csv('census.csv', index_col='FIPS')

# %%
df
# Out:
#                                           Geography  2017 Population  \
# FIPS
# 10100                       Aberdeen, SD Micro Area            42608
# 10140                       Aberdeen, WA Micro Area            71454
# 10180                        Abilene, TX Metro Area           169000
# 10220                            Ada, OK Micro Area            38289
# 10300                         Adrian, MI Micro Area            98585
# ...                                             ...              ...
# 49660  Youngstown-Warren-Boardman, OH-PA Metro Area           548821
# 49700                      Yuba City, CA Metro Area           170227
# 49740                           Yuma, AZ Metro Area           204281
# 49780                     Zanesville, OH Micro Area            85933
# 49820                         Zapata, TX Micro Area            14415
#
#        2017 Median Age  2017 Total households  2017 Median HHIncome  \
# FIPS
# ...

# %% [markdown]
# # Exploring DataFrames

# %%
df.head()
# Out:
#                      Geography  2017 Population  2017 Median Age  \
# FIPS
# 10100  Aberdeen, SD Micro Area            42608             37.8
# 10140  Aberdeen, WA Micro Area            71454             43.5
# 10180   Abilene, TX Metro Area           169000             33.9
# 10220       Ada, OK Micro Area            38289             35.5
# 10300    Adrian, MI Micro Area            98585             41.6
#
#        2017 Total households  2017 Median HHIncome  \
# FIPS
# 10100                  17907                 54533
# 10140                  28070                 45483
# 10180                  60369                 48156
# 10220                  14512                 46689
# 10300                  38115                 51339
#
#        2017 Average household size  2017 Total families  \
# FIPS
# 10100                         2.29                11172
# 10140                         2.44                17782
# 10180                         2.57                39949
# ...

# %% [markdown]
# This will show the first 5 lines of the df

# %%
df.head()
# Out:
#                      Geography  2017 Population  2017 Median Age  \
# FIPS
# 10100  Aberdeen, SD Micro Area            42608             37.8
# 10140  Aberdeen, WA Micro Area            71454             43.5
# 10180   Abilene, TX Metro Area           169000             33.9
# 10220       Ada, OK Micro Area            38289             35.5
# 10300    Adrian, MI Micro Area            98585             41.6
#
#        2017 Total households  2017 Median HHIncome  \
# FIPS
# 10100                  17907                 54533
# 10140                  28070                 45483
# 10180                  60369                 48156
# 10220                  14512                 46689
# 10300                  38115                 51339
#
#        2017 Average household size  2017 Total families  \
# FIPS
# 10100                         2.29                11172
# 10140                         2.44                17782
# 10180                         2.57                39949
# ...

# %%
df.head(10)
# Out:
#                                     Geography  2017 Population  \
# FIPS
# 10100                 Aberdeen, SD Micro Area            42608
# 10140                 Aberdeen, WA Micro Area            71454
# 10180                  Abilene, TX Metro Area           169000
# 10220                      Ada, OK Micro Area            38289
# 10300                   Adrian, MI Micro Area            98585
# 10420                    Akron, OH Metro Area           703398
# 10460               Alamogordo, NM Micro Area            65130
# 10500                   Albany, GA Metro Area           153776
# 10540                   Albany, OR Metro Area           121074
# 10580  Albany-Schenectady-Troy, NY Metro Area           881862
#
#        2017 Median Age  2017 Total households  2017 Median HHIncome  \
# FIPS
# 10100             37.8                  17907                 54533
# 10140             43.5                  28070                 45483
# ...

# %%
df.tail()
# Out:
#                                           Geography  2017 Population  \
# FIPS
# 49660  Youngstown-Warren-Boardman, OH-PA Metro Area           548821
# 49700                      Yuba City, CA Metro Area           170227
# 49740                           Yuma, AZ Metro Area           204281
# 49780                     Zanesville, OH Micro Area            85933
# 49820                         Zapata, TX Micro Area            14415
#
#        2017 Median Age  2017 Total households  2017 Median HHIncome  \
# FIPS
# 49660             43.9                 230549                 44947
# 49700             34.3                  58068                 53101
# 49740             34.1                  71670                 43253
# 49780             40.2                  34348                 43325
# 49820             29.4                   4457                 34550
#
#        2017 Average household size  2017 Total families  \
# FIPS
# 49660                         2.30               145081
# ...

# %%
len(df)
# Out:
# 917

# %%
df.shape
# Out:
# (917, 12)

# %%
df.describe()
# Out:
#        2017 Population  2017 Median Age  2017 Total households  \
# count     9.170000e+02       917.000000           9.170000e+02
# mean      3.294721e+05        38.818212           1.215258e+05
# std       1.110860e+06         4.933767           3.937578e+05
# min       1.297200e+04        24.400000           3.731000e+03
# 25%       4.034500e+04        36.000000           1.537500e+04
# 50%       7.601200e+04        39.000000           3.020400e+04
# 75%       1.844540e+05        41.600000           6.966200e+04
# max       2.019204e+07        66.400000           7.168027e+06
#
#        2017 Median HHIncome  2017 Average household size  2017 Total families  \
# count            917.000000                   917.000000         9.170000e+02
# mean           50162.984733                     2.542519         8.001179e+04
# std            10551.957266                     0.234669         2.613062e+05
# min            23558.000000                     2.050000         2.589000e+03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917 entries, 10100 to 49820
# Data columns (total 12 columns):
# Geography                                                917 non-null object
# 2017 Population                                          917 non-null int64
# 2017 Median Age                                          917 non-null float64
# 2017 Total households                                    917 non-null int64
# 2017 Median HHIncome                                     917 non-null int64
# 2017 Average household size                              917 non-null float64
# 2017 Total families                                      917 non-null int64
# 2017 Average family size                                 917 non-null float64
# 2017 Percent owner-occupied housing units                917 non-null float64
# 2017 Percent renter-occupied housing units               917 non-null float64
# 2017 Population 16 years and over                        917 non-null int64
# ...

# %% [markdown]
# # Selecting Columns

# %%
df['Geography']
# Out:
# FIPS
# 10100                         Aberdeen, SD Micro Area
# 10140                         Aberdeen, WA Micro Area
# 10180                          Abilene, TX Metro Area
# 10220                              Ada, OK Micro Area
# 10300                           Adrian, MI Micro Area
#                              ...
# 49660    Youngstown-Warren-Boardman, OH-PA Metro Area
# 49700                        Yuba City, CA Metro Area
# 49740                             Yuma, AZ Metro Area
# 49780                       Zanesville, OH Micro Area
# 49820                           Zapata, TX Micro Area
# Name: Geography, Length: 917, dtype: object

# %%
df.Geography
# Out:
# FIPS
# 10100                         Aberdeen, SD Micro Area
# 10140                         Aberdeen, WA Micro Area
# 10180                          Abilene, TX Metro Area
# 10220                              Ada, OK Micro Area
# 10300                           Adrian, MI Micro Area
#                              ...
# 49660    Youngstown-Warren-Boardman, OH-PA Metro Area
# 49700                        Yuba City, CA Metro Area
# 49740                             Yuma, AZ Metro Area
# 49780                       Zanesville, OH Micro Area
# 49820                           Zapata, TX Micro Area
# Name: Geography, Length: 917, dtype: object

# %%
df[['Geography', '2017 Population']]
# Out:
#                                           Geography  2017 Population
# FIPS
# 10100                       Aberdeen, SD Micro Area            42608
# 10140                       Aberdeen, WA Micro Area            71454
# 10180                        Abilene, TX Metro Area           169000
# 10220                            Ada, OK Micro Area            38289
# 10300                         Adrian, MI Micro Area            98585
# ...                                             ...              ...
# 49660  Youngstown-Warren-Boardman, OH-PA Metro Area           548821
# 49700                      Yuba City, CA Metro Area           170227
# 49740                           Yuma, AZ Metro Area           204281
# 49780                     Zanesville, OH Micro Area            85933
# 49820                         Zapata, TX Micro Area            14415
#
# [917 rows x 2 columns]

# %%
df[['Geography']]
# Out:
#                                           Geography
# FIPS
# 10100                       Aberdeen, SD Micro Area
# 10140                       Aberdeen, WA Micro Area
# 10180                        Abilene, TX Metro Area
# 10220                            Ada, OK Micro Area
# 10300                         Adrian, MI Micro Area
# ...                                             ...
# 49660  Youngstown-Warren-Boardman, OH-PA Metro Area
# 49700                      Yuba City, CA Metro Area
# 49740                           Yuma, AZ Metro Area
# 49780                     Zanesville, OH Micro Area
# 49820                         Zapata, TX Micro Area
#
# [917 rows x 1 columns]

# %% [markdown]
# # Renaming Columns

# %%
df.rename(columns={'2017 Population': 'Population'}, inplace=True)

# %%
df.head()
# Out:
#                      Geography  Population  2017 Median Age  \
# FIPS
# 10100  Aberdeen, SD Micro Area       42608             37.8
# 10140  Aberdeen, WA Micro Area       71454             43.5
# 10180   Abilene, TX Metro Area      169000             33.9
# 10220       Ada, OK Micro Area       38289             35.5
# 10300    Adrian, MI Micro Area       98585             41.6
#
#        2017 Total households  2017 Median HHIncome  \
# FIPS
# 10100                  17907                 54533
# 10140                  28070                 45483
# 10180                  60369                 48156
# 10220                  14512                 46689
# 10300                  38115                 51339
#
#        2017 Average household size  2017 Total families  \
# FIPS
# 10100                         2.29                11172
# 10140                         2.44                17782
# 10180                         2.57                39949
# ...

# %%
df.columns = ['geography', 'population', 'median_age', 
              'total_households', 'median_hh_income',
             'avg_hh_size', 'total_families', 'avg_family_size',
             'pct_owner_occupied_housing', 'pct_renter_occupied_housing',
             'pop_16_and_over', 'unemployment_rate']

# %%
df.head()
# Out:
#                      geography  population  median_age  total_households  \
# FIPS
# 10100  Aberdeen, SD Micro Area       42608        37.8             17907
# 10140  Aberdeen, WA Micro Area       71454        43.5             28070
# 10180   Abilene, TX Metro Area      169000        33.9             60369
# 10220       Ada, OK Micro Area       38289        35.5             14512
# 10300    Adrian, MI Micro Area       98585        41.6             38115
#
#        median_hh_income  avg_hh_size  total_families  avg_family_size  \
# FIPS
# 10100             54533         2.29           11172             2.89
# 10140             45483         2.44           17782             3.00
# 10180             48156         2.57           39949             3.12
# 10220             46689         2.54            9459             3.07
# 10300             51339         2.45           25130             3.00
#
#        pct_owner_occupied_housing  pct_renter_occupied_housing  \
# FIPS
# ...

# %%
df.avg_hh_size
# Out:
# FIPS
# 10100    2.29
# 10140    2.44
# 10180    2.57
# 10220    2.54
# 10300    2.45
#          ...
# 49660    2.30
# 49700    2.89
# 49740    2.77
# 49780    2.45
# 49820    3.23
# Name: avg_hh_size, Length: 917, dtype: float64

# %%
df.index.name = 'fips'

# %%
df.head()
# Out:
#                      geography  population  median_age  total_households  \
# fips
# 10100  Aberdeen, SD Micro Area       42608        37.8             17907
# 10140  Aberdeen, WA Micro Area       71454        43.5             28070
# 10180   Abilene, TX Metro Area      169000        33.9             60369
# 10220       Ada, OK Micro Area       38289        35.5             14512
# 10300    Adrian, MI Micro Area       98585        41.6             38115
#
#        median_hh_income  avg_hh_size  total_families  avg_family_size  \
# fips
# 10100             54533         2.29           11172             2.89
# 10140             45483         2.44           17782             3.00
# 10180             48156         2.57           39949             3.12
# 10220             46689         2.54            9459             3.07
# 10300             51339         2.45           25130             3.00
#
#        pct_owner_occupied_housing  pct_renter_occupied_housing  \
# fips
# ...

# %% [markdown]
# # Sorting Data

# %%
df.sort_values('population', ascending=False).head()
# Out:
#                                               geography  population  \
# fips
# 35620  New York-Newark-Jersey City, NY-NJ-PA Metro Area    20192042
# 31080     Los Angeles-Long Beach-Anaheim, CA Metro Area    13261538
# 16980     Chicago-Naperville-Elgin, IL-IN-WI Metro Area     9549229
# 19100        Dallas-Fort Worth-Arlington, TX Metro Area     7104415
# 26420   Houston-The Woodlands-Sugar Land, TX Metro Area     6636208
#
#        median_age  total_households  median_hh_income  avg_hh_size  \
# fips
# 35620        38.2           7168027             72205         2.76
# 31080        36.4           4320174             65331         3.02
# 16980        37.0           3481330             65757         2.70
# 19100        34.6           2494426             63870         2.81
# 26420        34.0           2271561             62922         2.89
#
#        total_families  avg_family_size  pct_owner_occupied_housing  \
# fips
# ...

# %%
df.sort_values('population', ascending=False).tail()
# Out:
#                        geography  population  median_age  total_households  \
# fips
# 46820  Vermillion, SD Micro Area       13907        25.0              5302
# 28540   Ketchikan, AK Micro Area       13745        39.5              5270
# 29500      Lamesa, TX Micro Area       13095        33.1              4339
# 18780       Craig, CO Micro Area       13056        37.7              5103
# 46900      Vernon, TX Micro Area       12972        37.2              5155
#
#        median_hh_income  avg_hh_size  total_families  avg_family_size  \
# fips
# 46820             41773         2.20            2599             2.84
# 28540             67321         2.55            3410             3.07
# 29500             43201         2.61            2958             3.20
# 18780             53010         2.53            3363             3.09
# 46900             43913         2.39            3320             2.97
#
#        pct_owner_occupied_housing  pct_renter_occupied_housing  \
# fips
# ...

# %%
df
# Out:
#                                           geography  population  median_age  \
# fips
# 10100                       Aberdeen, SD Micro Area       42608        37.8
# 10140                       Aberdeen, WA Micro Area       71454        43.5
# 10180                        Abilene, TX Metro Area      169000        33.9
# 10220                            Ada, OK Micro Area       38289        35.5
# 10300                         Adrian, MI Micro Area       98585        41.6
# ...                                             ...         ...         ...
# 49660  Youngstown-Warren-Boardman, OH-PA Metro Area      548821        43.9
# 49700                      Yuba City, CA Metro Area      170227        34.3
# 49740                           Yuma, AZ Metro Area      204281        34.1
# 49780                     Zanesville, OH Micro Area       85933        40.2
# 49820                         Zapata, TX Micro Area       14415        29.4
#
# ...

# %% [markdown]
# # Exporting Data

# %%
df.sort_values('population', ascending=False).to_csv('cities_by_population')

# %%
pd.read_csv('cities_by_population')
# Out:
#       fips                                         geography  population  \
# 0    35620  New York-Newark-Jersey City, NY-NJ-PA Metro Area    20192042
# 1    31080     Los Angeles-Long Beach-Anaheim, CA Metro Area    13261538
# 2    16980     Chicago-Naperville-Elgin, IL-IN-WI Metro Area     9549229
# 3    19100        Dallas-Fort Worth-Arlington, TX Metro Area     7104415
# 4    26420   Houston-The Woodlands-Sugar Land, TX Metro Area     6636208
# ..     ...                                               ...         ...
# 912  46820                         Vermillion, SD Micro Area       13907
# 913  28540                          Ketchikan, AK Micro Area       13745
# 914  29500                             Lamesa, TX Micro Area       13095
# 915  18780                              Craig, CO Micro Area       13056
# 916  46900                             Vernon, TX Micro Area       12972
#
#      median_age  total_households  median_hh_income  avg_hh_size  \
# ...

# %% [markdown]
# # Pandas Challenge #1 - Sort all the geographies by population and save only the geography, population, and media_hh_income columns of the 100 largest geographis to a CSV

# %%
df[['geography', 'population', 'median_hh_income']].sort_values('population', 
ascending=False).head(100).to_csv('pandas_challenge_1')

# %%
pd.read_csv('pandas_challenge_1')
# Out:
#      fips                                         geography  population  \
# 0   35620  New York-Newark-Jersey City, NY-NJ-PA Metro Area    20192042
# 1   31080     Los Angeles-Long Beach-Anaheim, CA Metro Area    13261538
# 2   16980     Chicago-Naperville-Elgin, IL-IN-WI Metro Area     9549229
# 3   19100        Dallas-Fort Worth-Arlington, TX Metro Area     7104415
# 4   26420   Houston-The Woodlands-Sugar Land, TX Metro Area     6636208
# ..    ...                                               ...         ...
# 95  25420                Harrisburg-Carlisle, PA Metro Area      565008
# 96  42540   Scranton--Wilkes-Barre--Hazleton, PA Metro Area      557942
# 97  20500                 Durham-Chapel Hill, NC Metro Area      550281
# 98  49660      Youngstown-Warren-Boardman, OH-PA Metro Area      548821
# 99  16860                     Chattanooga, TN-GA Metro Area      548359
#
#     median_hh_income
# 0              72205
# 1              65331
# 2              65757
# ...

# %% [markdown]
# # Running Functions on Columns

# %%
df['population'].mean()
# Out:
# 329472.1439476554

# %%
df.population.max()
# Out:
# 20192042

# %%
df['median_age'].astype(int)
# Out:
# fips
# 10100    37
# 10140    43
# 10180    33
# 10220    35
# 10300    41
#          ..
# 49660    43
# 49700    34
# 49740    34
# 49780    40
# 49820    29
# Name: median_age, Length: 917, dtype: int32

# %% [markdown]
# Other functions include:
# - min()
# - max()
# - std()
# - count()
# - round()
# - sample()

# %%
df['geography'].str.lower()
# Out:
# fips
# 10100                         aberdeen, sd micro area
# 10140                         aberdeen, wa micro area
# 10180                          abilene, tx metro area
# 10220                              ada, ok micro area
# 10300                           adrian, mi micro area
#                              ...
# 49660    youngstown-warren-boardman, oh-pa metro area
# 49700                        yuba city, ca metro area
# 49740                             yuma, az metro area
# 49780                       zanesville, oh micro area
# 49820                           zapata, tx micro area
# Name: geography, Length: 917, dtype: object

# %% [markdown]
# # Creating your own function

# %%
def add_one(number):
    return number + 1

# %%
df['median_age'].apply(add_one)
# Out:
# fips
# 10100    38.8
# 10140    44.5
# 10180    34.9
# 10220    36.5
# 10300    42.6
#          ...
# 49660    44.9
# 49700    35.3
# 49740    35.1
# 49780    41.2
# 49820    30.4
# Name: median_age, Length: 917, dtype: float64

# %% [markdown]
# # Adding and Removing Columns

# %%
df['pop_16_and_over'] / df['population']
# Out:
# fips
# 10100    0.790251
# 10140    0.813894
# 10180    0.788290
# 10220    0.785578
# 10300    0.811138
#            ...
# 49660    0.820623
# 49700    0.758475
# 49740    0.769044
# 49780    0.799192
# 49820    0.692820
# Length: 917, dtype: float64

# %%
df['pct_pop_16_and_over'] = df['pop_16_and_over'] / df['population']

# %%
df.head()
# Out:
#                      geography  population  median_age  total_households  \
# fips
# 10100  Aberdeen, SD Micro Area       42608        37.8             17907
# 10140  Aberdeen, WA Micro Area       71454        43.5             28070
# 10180   Abilene, TX Metro Area      169000        33.9             60369
# 10220       Ada, OK Micro Area       38289        35.5             14512
# 10300    Adrian, MI Micro Area       98585        41.6             38115
#
#        median_hh_income  avg_hh_size  total_families  avg_family_size  \
# fips
# 10100             54533         2.29           11172             2.89
# 10140             45483         2.44           17782             3.00
# 10180             48156         2.57           39949             3.12
# 10220             46689         2.54            9459             3.07
# 10300             51339         2.45           25130             3.00
#
#        pct_owner_occupied_housing  pct_renter_occupied_housing  \
# fips
# ...

# %%
df.drop(columns=['pct_pop_16_and_over'])
# Out:
#                                           geography  population  median_age  \
# fips
# 10100                       Aberdeen, SD Micro Area       42608        37.8
# 10140                       Aberdeen, WA Micro Area       71454        43.5
# 10180                        Abilene, TX Metro Area      169000        33.9
# 10220                            Ada, OK Micro Area       38289        35.5
# 10300                         Adrian, MI Micro Area       98585        41.6
# ...                                             ...         ...         ...
# 49660  Youngstown-Warren-Boardman, OH-PA Metro Area      548821        43.9
# 49700                      Yuba City, CA Metro Area      170227        34.3
# 49740                           Yuma, AZ Metro Area      204281        34.1
# 49780                     Zanesville, OH Micro Area       85933        40.2
# 49820                         Zapata, TX Micro Area       14415        29.4
#
# ...

# %% [markdown]
# # Selecting Rows

# %%
df[1:] # Skip the 1st row
# Out:
#                                           geography  population  median_age  \
# fips
# 10140                       Aberdeen, WA Micro Area       71454        43.5
# 10180                        Abilene, TX Metro Area      169000        33.9
# 10220                            Ada, OK Micro Area       38289        35.5
# 10300                         Adrian, MI Micro Area       98585        41.6
# 10420                          Akron, OH Metro Area      703398        40.2
# ...                                             ...         ...         ...
# 49660  Youngstown-Warren-Boardman, OH-PA Metro Area      548821        43.9
# 49700                      Yuba City, CA Metro Area      170227        34.3
# 49740                           Yuma, AZ Metro Area      204281        34.1
# 49780                     Zanesville, OH Micro Area       85933        40.2
# 49820                         Zapata, TX Micro Area       14415        29.4
#
# ...

# %%
df.population >= 500000 # this would display True or False if done normally
# Out:
# fips
# 10100    False
# 10140    False
# 10180    False
# 10220    False
# 10300    False
#          ...
# 49660     True
# 49700    False
# 49740    False
# 49780    False
# 49820    False
# Name: population, Length: 917, dtype: bool

# %%
df[df.population >= 500000] # Will only display census data for cities with population >= 500k
# Out:
#                                                geography  population  \
# fips
# 10420                               Akron, OH Metro Area      703398
# 10580             Albany-Schenectady-Troy, NY Metro Area      881862
# 10740                         Albuquerque, NM Metro Area      905049
# 10900       Allentown-Bethlehem-Easton, PA-NJ Metro Area      832790
# 12060       Atlanta-Sandy Springs-Roswell, GA Metro Area     5700990
# ...                                                  ...         ...
# 47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...     6090196
# 48620                             Wichita, KS Metro Area      642339
# 49180                       Winston-Salem, NC Metro Area      658195
# 49340                        Worcester, MA-CT Metro Area      934923
# 49660       Youngstown-Warren-Boardman, OH-PA Metro Area      548821
#
#        median_age  total_households  median_hh_income  avg_hh_size  \
# fips
# ...

# %%
# Combining multiple things
df[(df.median_age >= 20)& (df.median_age < 30 )]
# Out:
#                                      geography  population  median_age  \
# fips
# 11180                      Ames, IA Metro Area       95888        25.9
# 11900                    Athens, OH Micro Area       65563        28.6
# 15100                 Brookings, SD Micro Area       33697        26.7
# 16260                Cedar City, UT Micro Area       48504        29.1
# 17780     College Station-Bryan, TX Metro Area      248554        27.2
# 20580                Eagle Pass, TX Micro Area       57471        29.6
# 22780         Fort Leonard Wood, MO Micro Area       53132        27.6
# 25980                Hinesville, GA Metro Area       79977        28.6
# 27340              Jacksonville, NC Metro Area      192685        26.0
# 27920             Junction City, KS Micro Area       35796        26.4
# 28780                Kingsville, TX Micro Area       32104        28.0
# 28860                Kirksville, MO Micro Area       29887        29.1
# ...

# %%
len(df)
# Out:
# 917

# %%
df[(df.median_age < 20) | (df.median_age > 50)]
# Out:
#                                           geography  population  median_age  \
# fips
# 12700                Barnstable Town, MA Metro Area      213900        52.4
# 14820                        Brevard, NC Micro Area       33291        50.6
# 15060                      Brookings, OR Micro Area       22377        55.6
# 18900                     Crossville, TN Micro Area       58178        50.5
# 23240                 Fredericksburg, TX Micro Area       25939        50.2
# 23820           Gardnerville Ranchos, NV Micro Area       47632        50.8
# 26140              Homosassa Springs, FL Metro Area      141373        55.9
# 29420       Lake Havasu City-Kingman, AZ Metro Area      204691        50.4
# 34260                  Mountain Home, AR Micro Area       41093        51.8
# 35440                        Newport, OR Micro Area       47307        50.9
# 35840  North Port-Sarasota-Bradenton, FL Metro Area      768381        51.6
# ...

# %% [markdown]
# # Text Search

# %%
df[df.geography.str.contains("NY")]
# Out:
#                                               geography  population  \
# fips
# 10580            Albany-Schenectady-Troy, NY Metro Area      881862
# 11220                          Amsterdam, NY Micro Area       49500
# 12180                             Auburn, NY Micro Area       78319
# 12860                            Batavia, NY Micro Area       58537
# 13780                         Binghamton, NY Metro Area      245446
# 15380  Buffalo-Cheektowaga-Niagara Falls, NY Metro Area     1136670
# 18500                            Corning, NY Micro Area       97539
# 18660                           Cortland, NY Micro Area       48334
# 21300                             Elmira, NY Metro Area       86883
# 24020                        Glens Falls, NY Metro Area      126884
# 24100                       Gloversville, NY Micro Area       53955
# 26460                             Hudson, NY Micro Area       61481
# 27060                             Ithaca, NY Metro Area      104415
# ...

# %%
len(df[df.geography.str.contains("NY")])
# Out:
# 26

# %% [markdown]
# # Copying to a New DataFrame

# %%
df_ny = df[df.geography.str.contains("NY")].copy()

# %%
df_ny.sort_values('population', ascending=False)
# Out:
#                                               geography  population  \
# fips
# 35620  New York-Newark-Jersey City, NY-NJ-PA Metro Area    20192042
# 15380  Buffalo-Cheektowaga-Niagara Falls, NY Metro Area     1136670
# 40380                          Rochester, NY Metro Area     1080653
# 10580            Albany-Schenectady-Troy, NY Metro Area      881862
# 45060                           Syracuse, NY Metro Area      659262
# 46540                         Utica-Rome, NY Metro Area      295267
# 13780                         Binghamton, NY Metro Area      245446
# 28740                           Kingston, NY Metro Area      180129
# 27460         Jamestown-Dunkirk-Fredonia, NY Micro Area      130846
# 24020                        Glens Falls, NY Metro Area      126884
# 48060                Watertown-Fort Drum, NY Metro Area      116567
# 36300                 Ogdensburg-Massena, NY Micro Area      110817
# 27060                             Ithaca, NY Metro Area      104415
# ...

# %% [markdown]
# # Pandas 2 Challenge:
#
# Which geography has the highest median income?

# %%
df.sort_values('median_hh_income', ascending=False).head()
# Out:
#                                                geography  population  \
# fips
# 31060                          Los Alamos, NM Micro Area       18031
# 41940      San Jose-Sunnyvale-Santa Clara, CA Metro Area     1969897
# 47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...     6090196
# 44920                         Summit Park, UT Micro Area       39731
# 41860       San Francisco-Oakland-Hayward, CA Metro Area     4641820
#
#        median_age  total_households  median_hh_income  avg_hh_size  \
# fips
# 31060        43.0              7525            110190         2.38
# 41940        36.9            647891            105809         2.99
# 47900        36.7           2170034             97148         2.76
# 44920        38.8             14781             94952         2.67
# 41860        38.8           1684081             92714         2.71
#
#        total_families  avg_family_size  pct_owner_occupied_housing  \
# fips
# ...

# %%
df[df.median_hh_income == df.median_hh_income.max()]
# Out:
#                        geography  population  median_age  total_households  \
# fips
# 31060  Los Alamos, NM Micro Area       18031        43.0              7525
#
#        median_hh_income  avg_hh_size  total_families  avg_family_size  \
# fips
# 31060            110190         2.38            4969             2.99
#
#        pct_owner_occupied_housing  pct_renter_occupied_housing  \
# fips
# 31060                        73.7                         26.3
#
#        pop_16_and_over  unemployment_rate  pct_pop_16_and_over
# fips
# 31060            14444                3.7             0.801065

# %% [markdown]
# What large geography (1MM+) has the smallest average family size?

# %%
df[df.population > 1000000].sort_values('avg_family_size').head()
# Out:
#                                               geography  population  \
# fips
# 38300                         Pittsburgh, PA Metro Area     2348143
# 15380  Buffalo-Cheektowaga-Niagara Falls, NY Metro Area     1136670
# 40380                          Rochester, NY Metro Area     1080653
# 17460                   Cleveland-Elyria, OH Metro Area     2062764
# 41180                       St. Louis, MO-IL Metro Area     2804998
#
#        median_age  total_households  median_hh_income  avg_hh_size  \
# fips
# 38300        43.0           1000493             56073         2.28
# 15380        40.8            474349             53534         2.33
# 40380        39.9            431327             55256         2.41
# 17460        41.3            853766             52446         2.37
# 41180        39.0           1112971             59046         2.47
#
#        total_families  avg_family_size  pct_owner_occupied_housing  \
# fips
# ...

# %% [markdown]
# Which geographies in NY have the highest and lowest median age?

# %%
ny_df = df[df.geography.str.contains('NY')]

# %%
ny_df.sort_values('median_age', ascending=False).head() # Highest
# Out:
#                          geography  population  median_age  total_households  \
# fips
# 26460        Hudson, NY Micro Area       61481        47.4             25470
# 24020   Glens Falls, NY Metro Area      126884        44.8             51237
# 28740      Kingston, NY Metro Area      180129        43.6             69662
# 24100  Gloversville, NY Micro Area       53955        43.4             22535
# 12860       Batavia, NY Micro Area       58537        43.2             23951
#
#        median_hh_income  avg_hh_size  total_families  avg_family_size  \
# fips
# 26460             61093         2.32           16008             2.84
# 24020             56608         2.40           32801             2.92
# 28740             61652         2.42           43393             3.02
# 24100             48033         2.34           14438             2.81
# 12860             54033         2.41           15546             2.98
#
#        pct_owner_occupied_housing  pct_renter_occupied_housing  \
# ...

# %%
ny_df.sort_values('median_age').head() # Lowest
# Out:
#                                               geography  population  \
# fips
# 27060                             Ithaca, NY Metro Area      104415
# 48060                Watertown-Fort Drum, NY Metro Area      116567
# 18660                           Cortland, NY Micro Area       48334
# 36300                 Ogdensburg-Massena, NY Micro Area      110817
# 35620  New York-Newark-Jersey City, NY-NJ-PA Metro Area    20192042
#
#        median_age  total_households  median_hh_income  avg_hh_size  \
# fips
# 27060        30.4             38986             56200         2.33
# 48060        31.9             43206             50322         2.54
# 18660        36.2             17925             52451         2.50
# 36300        38.0             41638             48330         2.38
# 35620        38.2           7168027             72205         2.76
#
#        total_families  avg_family_size  pct_owner_occupied_housing  \
# fips
# ...

# %% [markdown]
# # Make a category variable for area

# %%
df['area'] = df['geography'].str[-10:]

# %%
df.head(3)
# Out:
#                      geography  population  median_age  total_households  \
# fips
# 10100  Aberdeen, SD Micro Area       42608        37.8             17907
# 10140  Aberdeen, WA Micro Area       71454        43.5             28070
# 10180   Abilene, TX Metro Area      169000        33.9             60369
#
#        median_hh_income  avg_hh_size  total_families  avg_family_size  \
# fips
# 10100             54533         2.29           11172             2.89
# 10140             45483         2.44           17782             3.00
# 10180             48156         2.57           39949             3.12
#
#        pct_owner_occupied_housing  pct_renter_occupied_housing  \
# fips
# 10100                        67.5                         32.5
# 10140                        66.1                         33.9
# 10180                        62.4                         37.6
#
#        pop_16_and_over  unemployment_rate  pct_pop_16_and_over        area
# fips
# ...

# %% [markdown]
# # Grouping

# %%
df.population.mean()
# Out:
# 329472.1439476554

# %%
df.groupby('area').population.mean()
# Out:
# area
# Metro Area    719825.905759
# Micro Area     50752.261682
# Name: population, dtype: float64

# %% [markdown]
# # Plotting with matplotlib

# %%
# %matplotlib inline

# %%
df.plot()

# %%
df.plot(y = 'population')

# %%
df.plot(y = ['avg_hh_size', 'avg_family_size'])

# %%
df.plot(y = ['avg_hh_size', 'avg_family_size'], kind = 'box')

# %%
df.plot(x = 'median_age', y = 'total_households', kind = 'scatter')

# %% [markdown]
# # Plotting with Seaborn

# %%
import seaborn as sns

# %%
sns.lmplot(data = df, x = 'population', y = 'total_households', hue = 'area')

# %%
sns.lmplot(data = df, x = 'unemployment_rate', y = 'median_hh_income', hue = 'area')

# %%
sns.pairplot(df, height = 3)

# %%
sns.pairplot(df, vars = ['population', 'median_age', 'total_households'], kind = "reg", height = 2, hue = "area")

# %%
df.corr()
# Out:
#                              population  median_age  total_households  \
# population                     1.000000   -0.065339          0.998250
# median_age                    -0.065339    1.000000         -0.057325
# total_households               0.998250   -0.057325          1.000000
# median_hh_income               0.296899   -0.028034          0.302194
# avg_hh_size                    0.152034   -0.530618          0.134966
# total_families                 0.999305   -0.060573          0.999389
# avg_family_size                0.185892   -0.537568          0.171993
# pct_owner_occupied_housing    -0.211483    0.616492         -0.206404
# pct_renter_occupied_housing    0.211483   -0.616492          0.206404
# pop_16_and_over                0.999777   -0.060789          0.998381
# unemployment_rate             -0.004732   -0.018933         -0.009653
# pct_pop_16_and_over           -0.025800    0.542814         -0.015910
#
# ...

# %%
all_corrs = df.corr()
sns.heatmap(all_corrs, cmap = "YlGnBu")

# %%
sns.violinplot(data = df, x = 'area', y = 'avg_family_size')

# %%
sns.boxplot(data = df, x = 'area', y = 'avg_family_size')

# %%
sns.swarmplot(data = df, x = 'area', y = 'population')

# %% [markdown]
# # Regressions
