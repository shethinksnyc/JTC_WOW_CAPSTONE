# %%
import pandas as pd  # import pandas library as pd
import numpy as np # import numpy library as np
import matplotlib.pyplot as plt # import matplotlib.pyplot library as plt
import matplotlib as mpl # import matplotlib library as mpl

# %%
def float_to_int(x): # function to convert float to integer (i.e.: 2014.0 to 2014)
    split_string = x.split(".") # splits input argument at decimal point, returns an array (i.e.: 2014.0 to [2014, 0])
    substring = split_string[0] # takes the value at the index 0 of new array (i.e.: 2014 of [2014, 0])
    if len(substring) > 0: # if the length of the substring is greater then 0 (which means, in the case that there is data in that cell) 
        return int(substring) # convert the substring to an integer, and return that integer
    else: # otherwise (in the case that there is no data in that cell)
        return '' # return an empty string

all_cities_full = pd.read_csv('clean_city_data.csv', converters={'calendar_year': float_to_int}) # read csv and call the float_to_int function on the column calendar_year
all_cities_full # display csv
# Out:
#        calendar_year         city state closed_date  amount_awarded
# 0               2019  Baton Rouge    LA  2019-07-08        45640.50
# 1               2019  Baton Rouge    LA  2019-08-14        30445.62
# 2               2019  Baton Rouge    LA  2019-02-27        52504.00
# 3               2018  Baton Rouge    LA  2018-12-11        20000.00
# 4               2018  Baton Rouge    LA  2018-07-16       107795.30
# ...              ...          ...   ...         ...             ...
# 39011           2015        Miami    FL  2015-03-17        80000.00
# 39012           2017        Miami    FL  2017-03-15        19750.00
# 39013           2020        Miami    FL  2020-04-07       300000.00
# 39014           2018        Miami    FL  2018-08-03        50000.00
# 39015           2018        Miami    FL  2018-10-30        17500.00
#
# [39016 rows x 5 columns]

# %%
boston_filter = all_cities_full[all_cities_full.city == "Boston"] # filters through the csv and pulls all the data with the string "Boston" in the city column
boston_sum = boston_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
boston_line = boston_sum.plot() # plots the data from boston_sum (line graph is the default plot on matplotlib)
boston_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
boston_line.set_title('Boston: Total Payout For Police Misconduct By Year') # names the title of the graph
boston_line.set_xlabel('Year') # names the x axis
boston_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
chicago_filter = all_cities_full[all_cities_full.city == "Chicago"] # filters through the csv and pulls all the data with the string "Chicago" in the city column
chicago_sum = chicago_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
chicago_line = chicago_sum.plot() # plots the data from chicago_sum (line graph is the default plot on matplotlib)
chicago_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
chicago_line.set_title('Chicago: Total Payout For Police Misconduct By Year') # names the title of the graph
chicago_line.set_xlabel('Year') # names the x axis
chicago_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
miami_filter = all_cities_full[all_cities_full.city == "Miami"] # filters through the csv and pulls all the data with the string "Miami" in the city column
miami_sum = miami_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
miami_line = miami_sum.plot() # plots the data from miami_sum (line graph is the default plot on matplotlib)
miami_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
miami_line.set_title('Miami: Total Payout For Police Misconduct By Year') # names the title of the graph
miami_line.set_xlabel('Year') # names the x axis
miami_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
los_angeles_filter = all_cities_full[all_cities_full.city == "Los Angeles"] # filters through the csv and pulls all the data with the string "Los Angeles" in the city column
los_angeles_sum = los_angeles_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
los_angeles_line = los_angeles_sum.plot() # plots the data from los_angeles_sum (line graph is the default plot on matplotlib)
los_angeles_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
los_angeles_line.set_title('Los Angeles: Total Payout For Police Misconduct By Year') # names the title of the graph
los_angeles_line.set_xlabel('Year') # names the x axis
los_angeles_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
charleston_filter = all_cities_full[all_cities_full.city == "Charleston"] # filters through the csv and pulls all the data with the string "Charleston" in the city column
charleston_sum = charleston_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
charleston_line = charleston_sum.plot() # plots the data from charleston_sum (line graph is the default plot on matplotlib)
charleston_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
charleston_line.set_title('Charleston: Total Payout For Police Misconduct By Year') # names the title of the graph
charleston_line.set_xlabel('Year') # names the x axis
charleston_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
cincinnati_filter = all_cities_full[all_cities_full.city == "Cincinnati"] # filters through the csv and pulls all the data with the string "Cincinnati" in the city column
cincinnati_sum = cincinnati_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
cincinnati_line = cincinnati_sum.plot() # plots the data from charleston_sum (line graph is the default plot on matplotlib)
cincinnati_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
cincinnati_line.set_title('Cincinnati: Total Payout For Police Misconduct By Year') # names the title of the graph
cincinnati_line.set_xlabel('Year') # names the x axis
cincinnati_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
columbia_filter = all_cities_full[all_cities_full.city == "Columbia"] # filters through the csv and pulls all the data with the string "Columbia" in the city column
columbia_sum = columbia_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
columbia_sum.drop(columbia_sum.tail(1).index, inplace = True) # removes the last row that shows the sum of the amount awarded for the cases that do not have a calendar year value stored
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
columbia_line = columbia_sum.plot() # plots the data from columbia_sum (line graph is the default plot on matplotlib)
columbia_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
columbia_line.set_title('Columbia: Total Payout For Police Misconduct By Year') # names the title of the graph
columbia_line.set_xlabel('Year') # names the x axis
columbia_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
orlando_filter = all_cities_full[all_cities_full.city == "Orlando"] # filters through the csv and pulls all the data with the string "Orlando" in the city column
orlando_sum = orlando_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
orlando_sum.drop(orlando_sum.tail(1).index, inplace = True) # removes the last row that shows the sum of the amount awarded for the cases that do not have a calendar year value stored
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
orlando_line = orlando_sum.plot() # plots the data from orlando_sum (line graph is the default plot on matplotlib)
orlando_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
orlando_line.set_title('Orlando: Total Payout For Police Misconduct By Year') # names the title of the graph
orlando_line.set_xlabel('Year') # names the x axis
orlando_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
atlanta_filter = all_cities_full[all_cities_full.city == "Atlanta"] # filters through the csv and pulls all the data with the string "Atlanta" in the city column
atlanta_sum = atlanta_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
atlanta_line = atlanta_sum.plot() # plots the data from atlanta_sum (line graph is the default plot on matplotlib)
atlanta_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
atlanta_line.set_title('Atlanta: Total Payout For Police Misconduct By Year') # names the title of the graph
atlanta_line.set_xlabel('Year') # names the x axis
atlanta_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
baltimore_filter = all_cities_full[all_cities_full.city == "Baltimore"] # filters through the csv and pulls all the data with the string "Baltimore" in the city column
baltimore_sum = baltimore_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
baltimore_line = baltimore_sum.plot() # plots the data from baltimore_sum (line graph is the default plot on matplotlib)
baltimore_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
baltimore_line.set_title('Baltimore: Total Payout For Police Misconduct By Year') # names the title of the graph
baltimore_line.set_xlabel('Year') # names the x axis
baltimore_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
baton_rouge_filter = all_cities_full[all_cities_full.city == "Baton Rouge"] # filters through the csv and pulls all the data with the string "Baton Rouge" in the city column
baton_rouge_sum = baton_rouge_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
baton_rouge_line = baton_rouge_sum.plot() # plots the data from baton_rouge_sum (line graph is the default plot on matplotlib)
baton_rouge_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
baton_rouge_line.set_title('Baton Rouge: Total Payout For Police Misconduct By Year') # names the title of the graph
baton_rouge_line.set_xlabel('Year') # names the x axis
baton_rouge_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
cleveland_filter = all_cities_full[all_cities_full.city == "Cleveland"] # filters through the csv and pulls all the data with the string "Cleveland" in the city column
cleveland_sum = cleveland_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
cleveland_line = cleveland_sum.plot() # plots the data from cleveland_sum (line graph is the default plot on matplotlib)
cleveland_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
cleveland_line.set_title('Cleveland: Total Payout For Police Misconduct By Year') # names the title of the graph
cleveland_line.set_xlabel('Year') # names the x axis
cleveland_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
detroit_filter = all_cities_full[all_cities_full.city == "Detroit"] # filters through the csv and pulls all the data with the string "Detroit" in the city column
detroit_sum = detroit_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
detroit_line = detroit_sum.plot() # plots the data from detroit_sum (line graph is the default plot on matplotlib)
detroit_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
detroit_line.set_title('Detroit: Total Payout For Police Misconduct By Year') # names the title of the graph
detroit_line.set_xlabel('Year') # names the x axis
detroit_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
fort_lauderdale_filter = all_cities_full[all_cities_full.city == "Fort Lauderdale"] # filters through the csv and pulls all the data with the string "Fort Lauderdale" in the city column
fort_lauderdale_sum = fort_lauderdale_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
fort_lauderdale_line = fort_lauderdale_sum.plot() # plots the data from fort_lauderdale_sum (line graph is the default plot on matplotlib)
fort_lauderdale_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
fort_lauderdale_line.set_title('Fort Lauderdale: Total Payout For Police Misconduct By Year') # names the title of the graph
fort_lauderdale_line.set_xlabel('Year') # names the x axis
fort_lauderdale_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
indianapolis_filter = all_cities_full[all_cities_full.city == "Indianapolis"] # filters through the csv and pulls all the data with the string "Indianapolis" in the city column
indianapolis_sum = indianapolis_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
indianapolis_line = indianapolis_sum.plot() # plots the data from indianapolis_sum (line graph is the default plot on matplotlib)
indianapolis_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
indianapolis_line.set_title('Indianapolis: Total Payout For Police Misconduct By Year') # names the title of the graph
indianapolis_line.set_xlabel('Year') # names the x axis
indianapolis_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
memphis_filter = all_cities_full[all_cities_full.city == "Memphis"] # filters through the csv and pulls all the data with the string "Memphis" in the city column
memphis_sum = memphis_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
memphis_line = memphis_sum.plot() # plots the data from memphis_sum (line graph is the default plot on matplotlib)
memphis_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
memphis_line.set_title('Memphis: Total Payout For Police Misconduct By Year') # names the title of the graph
memphis_line.set_xlabel('Year') # names the x axis
memphis_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
milwaukee_filter = all_cities_full[all_cities_full.city == "Milwaukee"] # filters through the csv and pulls all the data with the string "Memphis" in the city column
milwaukee_sum = milwaukee_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
milwaukee_line = milwaukee_sum.plot() # plots the data from milwaukee_sum (line graph is the default plot on matplotlib)
milwaukee_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
milwaukee_line.set_title('Milwaukee: Total Payout For Police Misconduct By Year') # names the title of the graph
milwaukee_line.set_xlabel('Year') # names the x axis
milwaukee_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
new_orleans_filter = all_cities_full[all_cities_full.city == "New Orleans"] # filters through the csv and pulls all the data with the string "New Orleans" in the city column
new_orleans_sum = new_orleans_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
new_orleans_line = new_orleans_sum.plot() # plots the data from new_orleans_sum (line graph is the default plot on matplotlib)
new_orleans_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
new_orleans_line.set_title('New Orleans: Total Payout For Police Misconduct By Year') # names the title of the graph
new_orleans_line.set_xlabel('Year') # names the x axis
new_orleans_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
new_york_city_filter = all_cities_full[all_cities_full.city == "New York City"] # filters through the csv and pulls all the data with the string "New York City" in the city column
new_york_city_sum = new_york_city_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
new_york_city_line = new_york_city_sum.plot() # plots the data from new_york_city_sum (line graph is the default plot on matplotlib)
new_york_city_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
new_york_city_line.set_title('New York City: Total Payout For Police Misconduct By Year') # names the title of the graph
new_york_city_line.set_xlabel('Year') # names the x axis
new_york_city_line.set_ylabel('Amount Awarded') # names y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
north_charleston_filter = all_cities_full[all_cities_full.city == "North Charleston"] # filters through the csv and pulls all the data with the string "North Charleston" in the city column
north_charleston_sum = north_charleston_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
north_charleston_line = north_charleston_sum.plot() # plots the data from north_charleston_sum (line graph is the default plot on matplotlib)
north_charleston_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
north_charleston_line.set_title('North Charleston: Total Payout For Police Misconduct By Year') # names the title of the graph
north_charleston_line.set_xlabel('Year') # names the x axis
north_charleston_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
paterson_filter = all_cities_full[all_cities_full.city == "Paterson"] # filters through the csv and pulls all the data with the string "Paterson" in the city column
paterson_sum = paterson_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
paterson_line = paterson_sum.plot() # plots the data from paterson_sum (line graph is the default plot on matplotlib)
paterson_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
paterson_line.set_title('Paterson: Total Payout For Police Misconduct By Year') # names the title of the graph
paterson_line.set_xlabel('Year') # names the x axis
paterson_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
philadelphia_filter = all_cities_full[all_cities_full.city == "Philadelphia"] # filters through the csv and pulls all the data with the string "Philadelphia" in the city column
philadelphia_sum = philadelphia_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
philadelphia_line = philadelphia_sum.plot() # plots the data from philadelphia_sum (line graph is the default plot on matplotlib)
philadelphia_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
philadelphia_line.set_title('Philadelphia: Total Payout For Police Misconduct By Year') # names the title of the graph
philadelphia_line.set_xlabel('Year') # names the x axis
philadelphia_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
richmond_filter = all_cities_full[all_cities_full.city == "Richmond"] # filters through the csv and pulls all the data with the string "Richmond" in the city column
richmond_sum = richmond_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
richmond_line = richmond_sum.plot() # plots the data from richmond_sum (line graph is the default plot on matplotlib)
richmond_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
richmond_line.set_title('Richmond: Total Payout For Police Misconduct By Year') # names the title of the graph
richmond_line.set_xlabel('Year') # names the x axis
richmond_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
san_francisco_filter = all_cities_full[all_cities_full.city == "San Francisco"] # filters through the csv and pulls all the data with the string "San Francisco" in the city column
san_francisco_sum = san_francisco_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
san_francisco_line = san_francisco_sum.plot() # plots the data from san_francisco_sum (line graph is the default plot on matplotlib)
san_francisco_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
san_francisco_line.set_title('San Francisco: Total Payout For Police Misconduct By Year') # names the title of the graph
san_francisco_line.set_xlabel('Year') # names the x axis
san_francisco_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
springfield_filter = all_cities_full[all_cities_full.city == "Springfield"] # filters through the csv and pulls all the data with the string "Springfield" in the city column
springfield_sum = springfield_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
springfield_line = springfield_sum.plot() # plots the data from springfield_sum (line graph is the default plot on matplotlib)
springfield_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
springfield_line.set_title('Springfield: Total Payout For Police Misconduct By Year') # names the title of the graph
springfield_line.set_xlabel('Year') # names the x axis
springfield_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
st_louis_filter = all_cities_full[all_cities_full.city == "St. Louis"] # filters through the csv and pulls all the data with the string "St. Louis" in the city column
st_louis_sum = st_louis_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
st_louis_line = st_louis_sum.plot() # plots the data from st_louis_sum (line graph is the default plot on matplotlib)
st_louis_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
st_louis_line.set_title('St. Louis: Total Payout For Police Misconduct By Year') # names the title of the graph
st_louis_line.set_xlabel('Year') # names the x axis
st_louis_line.set_xticks([2016,2017,2018,2019]) # set x ticks
st_louis_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
washington_filter = all_cities_full[all_cities_full.city == "Washington"] # filters through the csv and pulls all the data with the string "Washington" in the city column
washington_sum = washington_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
washington_line = washington_sum.plot() # plots the data from washington_sum (line graph is the default plot on matplotlib)
washington_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
washington_line.set_title('Washington: Total Payout For Police Misconduct By Year') # names the title of the graph
washington_line.set_xlabel('Year') # names the x axis
washington_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')

# %%
waterbury_filter = all_cities_full[all_cities_full.city == "Waterbury"] # filters through the csv and pulls all the data with the string "Waterbury" in the city column
waterbury_sum = waterbury_filter.groupby(['calendar_year'])[['amount_awarded']].sum().round() # calculated the sum of the amount awarded for each calendar year and rounded it (used to get flat numbers)
plt.rcParams['figure.figsize'] = [7, 6] # controls the size of the graph
waterbury_line = waterbury_sum.plot() # plots the data from waterbury_sum (line graph is the default plot on matplotlib)
waterbury_line.yaxis.set_major_formatter('${x:,.0f}') # inserts $ value with commas and 0 zeros after the decimal point on the y axis (amount awarded)
waterbury_line.set_title('Waterbury: Total Payout For Police Misconduct By Year') # names the title of the graph
waterbury_line.set_xlabel('Year') # names the x axis
waterbury_line.set_ylabel('Amount Awarded') # names the y axis
# Out:
# Text(0, 0.5, 'Amount Awarded')
